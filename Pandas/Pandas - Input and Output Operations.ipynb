# %%
pwd
# Out:
# 'C:\\Users\\acer\\Desktop\\Lokesh  ML docs\\Pandas'

# %%
import pandas as pd

# %% [markdown]
# ## CSV i/o

# %%
pd.read_csv('nba.csv').head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
df=pd.read_csv('nba.csv').head(10)

# %%
df.to_csv('MY_output',index=False)

# %%
pd.read_csv('My_output')
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %% [markdown]
# # exel/.xlsx I/O

# %%
pd.read_excel('nba.xlsx',sheet_name='nba')
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2020-06-02 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2020-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2020-06-05 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2020-06-05 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2020-06-10 00:00:00
# 5   Amir Johnson  Boston Celtics      90       PF   29  2020-06-09 00:00:00
# 6  Jordan Mickey  Boston Celtics      55       PF   21  2020-06-08 00:00:00
# 7   Kelly Olynyk  Boston Celtics      41        C   25                  7-0
#
#    Weight            College      Salary
# 0     180              Texas   7730337.0
# 1     235          Marquette   6796117.0
# 2     205  Boston University         NaN
# 3     185      Georgia State   1148640.0
# 4     231                NaN   5000000.0
# ...

# %%
df.to_excel('Exel_writeSample.xlsx',sheet_name='NewSheet')

# %% [markdown]
# # HTML I/O

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0].head(10)
# Out:
#                                            Bank Name           City  ST  \
# 0                               The First State Bank  Barboursville  WV
# 1                                 Ericson State Bank        Ericson  NE
# 2                   City National Bank of New Jersey         Newark  NJ
# 3                                      Resolute Bank         Maumee  OH
# 4                              Louisa Community Bank         Louisa  KY
# 5                               The Enloe State Bank         Cooper  TX
# 6                Washington Federal Bank for Savings        Chicago  IL
# 7    The Farmers and Merchants State Bank of Argonia        Argonia  KS
# 8                                Fayette County Bank     Saint Elmo  IL
# 9  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...      Milwaukee  WI
#
#     CERT                Acquiring Institution       Closing Date
# 0  14361                       MVB Bank, Inc.      April 3, 2020
# ...
